# %%
# !pip3 install deeplake
# Out:
# Collecting deeplake
#   Downloading deeplake-3.2.21.tar.gz (455 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 455.8/455.8 kB 3.3 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /Users/sandrobarreshamers/opt/anaconda3/envs/fake_new/lib/python3.8/site-packages (from deeplake) (1.21.5)
# Requirement already satisfied: pillow in /Users/sandrobarreshamers/opt/anaconda3/envs/fake_new/lib/python3.8/site-packages (from deeplake) (9.3.0)
# Requirement already satisfied: boto3 in /Users/sandrobarreshamers/opt/anaconda3/envs/fake_new/lib/python3.8/site-packages (from deeplake) (1.24.28)
# Requirement already satisfied: click in /Users/sandrobarreshamers/opt/anaconda3/envs/fake_new/lib/python3.8/site-packages (from deeplake) (8.0.4)
# Collecting pathos
#   Downloading pathos-0.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 1.6 MB/s eta 0:00:00a 0:00:01
# Collecting humbug>=0.2.6
#   Downloading humbug-0.3.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: tqdm in /Users/sandrobarreshamers/opt/anaconda3/envs/fake_new/lib/python3.8/site-packages (from deeplake) (4.64.1)
# Collecting numcodecs
#   Downloading numcodecs-0.11.0-cp38-cp38-macosx_10_9_x86_64.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 2.3 MB/s eta 0:00:0000:0100:01
# Collecting pyjwt
#   Downloading PyJWT-2.6.0-py3-none-any.whl (20 kB)
# Collecting aioboto3==10.4.0
#   Downloading aioboto3-10.4.0-py3-none-any.whl (32 kB)
# Requirement already satisfied: nest_asyncio in /Users/sandrobarreshamers/opt/anaconda3/envs/fake_new/lib/python3.8/site-packages (from deeplake) (1.5.6)
# Collecting aiobotocore[boto3]==2.4.2
#   Downloading aiobotocore-2.4.2-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp>=3.3.1 in /Users/sandrobarreshamers/opt/anaconda3/envs/fake_new/lib/python3.8/site-packages (from aiobotocore[boto3]==2.4.2->aioboto3==10.4.0->deeplake) (3.8.4)
# Collecting aioitertools>=0.5.1
#   Downloading aioitertools-0.11.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: wrapt>=1.10.10 in /Users/sandrobarreshamers/opt/anaconda3/envs/fake_new/lib/python3.8/site-packages (from aiobotocore[boto3]==2.4.2->aioboto3==10.4.0->deeplake) (1.14.1)
# Requirement already satisfied: botocore<1.27.60,>=1.27.59 in /Users/sandrobarreshamers/opt/anaconda3/envs/fake_new/lib/python3.8/site-packages (from aiobotocore[boto3]==2.4.2->aioboto3==10.4.0->deeplake) (1.27.59)
# Collecting boto3
#   Downloading boto3-1.24.59-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.5/132.5 kB 3.0 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/sandrobarreshamers/opt/anaconda3/envs/fake_new/lib/python3.8/site-packages (from boto3->deeplake) (0.10.0)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /Users/sandrobarreshamers/opt/anaconda3/envs/fake_new/lib/python3.8/site-packages (from boto3->deeplake) (0.6.0)
# Requirement already satisfied: requests in /Users/sandrobarreshamers/opt/anaconda3/envs/fake_new/lib/python3.8/site-packages (from humbug>=0.2.6->deeplake) (2.28.1)
# Requirement already satisfied: entrypoints in /Users/sandrobarreshamers/opt/anaconda3/envs/fake_new/lib/python3.8/site-packages (from numcodecs->deeplake) (0.4)
# Collecting pox>=0.3.2
#   Downloading pox-0.3.2-py3-none-any.whl (29 kB)
# Collecting multiprocess>=0.70.14
#   Downloading multiprocess-0.70.14-py38-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.0/132.0 kB 3.1 MB/s eta 0:00:00a 0:00:01
# Collecting ppft>=1.7.6.6
#   Downloading ppft-1.7.6.6-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: dill>=0.3.6 in /Users/sandrobarreshamers/opt/anaconda3/envs/fake_new/lib/python3.8/site-packages (from pathos->deeplake) (0.3.6)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /Users/sandrobarreshamers/opt/anaconda3/envs/fake_new/lib/python3.8/site-packages (from botocore<1.27.60,>=1.27.59->aiobotocore[boto3]==2.4.2->aioboto3==10.4.0->deeplake) (1.26.14)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/sandrobarreshamers/opt/anaconda3/envs/fake_new/lib/python3.8/site-packages (from botocore<1.27.60,>=1.27.59->aiobotocore[boto3]==2.4.2->aioboto3==10.4.0->deeplake) (2.8.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sandrobarreshamers/opt/anaconda3/envs/fake_new/lib/python3.8/site-packages (from requests->humbug>=0.2.6->deeplake) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/sandrobarreshamers/opt/anaconda3/envs/fake_new/lib/python3.8/site-packages (from requests->humbug>=0.2.6->deeplake) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sandrobarreshamers/opt/anaconda3/envs/fake_new/lib/python3.8/site-packages (from requests->humbug>=0.2.6->deeplake) (2022.12.7)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/sandrobarreshamers/opt/anaconda3/envs/fake_new/lib/python3.8/site-packages (from aiohttp>=3.3.1->aiobotocore[boto3]==2.4.2->aioboto3==10.4.0->deeplake) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/sandrobarreshamers/opt/anaconda3/envs/fake_new/lib/python3.8/site-packages (from aiohttp>=3.3.1->aiobotocore[boto3]==2.4.2->aioboto3==10.4.0->deeplake) (22.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/sandrobarreshamers/opt/anaconda3/envs/fake_new/lib/python3.8/site-packages (from aiohttp>=3.3.1->aiobotocore[boto3]==2.4.2->aioboto3==10.4.0->deeplake) (1.3.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/sandrobarreshamers/opt/anaconda3/envs/fake_new/lib/python3.8/site-packages (from aiohttp>=3.3.1->aiobotocore[boto3]==2.4.2->aioboto3==10.4.0->deeplake) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/sandrobarreshamers/opt/anaconda3/envs/fake_new/lib/python3.8/site-packages (from aiohttp>=3.3.1->aiobotocore[boto3]==2.4.2->aioboto3==10.4.0->deeplake) (1.8.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/sandrobarreshamers/opt/anaconda3/envs/fake_new/lib/python3.8/site-packages (from aiohttp>=3.3.1->aiobotocore[boto3]==2.4.2->aioboto3==10.4.0->deeplake) (6.0.4)
# Requirement already satisfied: typing_extensions>=4.0 in /Users/sandrobarreshamers/opt/anaconda3/envs/fake_new/lib/python3.8/site-packages (from aioitertools>=0.5.1->aiobotocore[boto3]==2.4.2->aioboto3==10.4.0->deeplake) (4.4.0)
# Requirement already satisfied: six>=1.5 in /Users/sandrobarreshamers/opt/anaconda3/envs/fake_new/lib/python3.8/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.27.60,>=1.27.59->aiobotocore[boto3]==2.4.2->aioboto3==10.4.0->deeplake) (1.16.0)
# Building wheels for collected packages: deeplake
#   Building wheel for deeplake (setup.py) ... done
#   Created wheel for deeplake: filename=deeplake-3.2.21-py3-none-any.whl size=554088 sha256=9c255b18001155096cfd9799a86ad1595c45eb5a0da0b7af427fab23cc9070ba
#   Stored in directory: /Users/sandrobarreshamers/Library/Caches/pip/wheels/10/28/f5/978ed6a60c549e207c299321102f63375366310ca2beb38a50
# Successfully built deeplake
# Installing collected packages: pyjwt, ppft, pox, numcodecs, multiprocess, aioitertools, pathos, humbug, aiobotocore, boto3, aioboto3, deeplake
#   Attempting uninstall: boto3
#     Found existing installation: boto3 1.24.28
#     Uninstalling boto3-1.24.28:
#       Successfully uninstalled boto3-1.24.28
# Successfully installed aioboto3-10.4.0 aiobotocore-2.4.2 aioitertools-0.11.0 boto3-1.24.59 deeplake-3.2.21 humbug-0.3.0 multiprocess-0.70.14 numcodecs-0.11.0 pathos-0.3.0 pox-0.3.2 ppft-1.7.6.6 pyjwt-2.6.0

# %%
import deeplake
ds = deeplake.load('hub://activeloop/liar-train')
# Out:
# This dataset can be visualized in Jupyter Notebook by ds.visualize() or at https://app.activeloop.ai/activeloop/liar-train
#
# hub://activeloop/liar-train loaded successfully.

# %%
df = pd.read_table('https://raw.githubusercontent.com/tfs4/liar_dataset/master/train.tsv')

# %%
df.columns
# Out:
# Index(['2635.json', 'false',
#        'Says the Annies List political group supports third-trimester abortions on demand.',
#        'abortion', 'dwayne-bohac', 'State representative', 'Texas',
#        'republican', '0', '1', '0.1', '0.2', '0.3', 'a mailer'],
#       dtype='object')

# %%
df.columns =['json_id', 'claim', 'object', 'topic', 'speaker', 'job_title (string)','state_info (string)','party_affiliation (string)','barely_true_counts (float32)','false_counts (float32)','half_true_counts (float32)','	mostly_true_counts (float32)','	pants_on_fire_counts (float32)','context (string)']

# %%
df.head()
# Out:
#       json_id        claim                                             object  \
# 0  10540.json    half-true  When did the decline of coal start? It started...
# 1    324.json  mostly-true  Hillary Clinton agrees with John McCain "by vo...
# 2   1123.json        false  Health care reform legislation is likely to ma...
# 3   9028.json    half-true  The economic turnaround started at the end of ...
# 4  12465.json         true  The Chicago Bears have had more starting quart...
#
#                                 topic         speaker  \
# 0  energy,history,job-accomplishments  scott-surovell
# 1                      foreign-policy    barack-obama
# 2                         health-care    blog-posting
# 3                        economy,jobs   charlie-crist
# 4                           education       robin-vos
#
#            job_title (string) state_info (string) party_affiliation (string)  \
# 0              State delegate            Virginia                   democrat
# 1                   President            Illinois                   democrat
# 2                         NaN                 NaN                       none
# 3                         NaN             Florida                   democrat
# 4  Wisconsin Assembly speaker           Wisconsin                 republican
#
#    barely_true_counts (float32)  false_counts (float32)  \
# 0                           0.0                     0.0
# 1                          70.0                    71.0
# 2                           7.0                    19.0
# 3                          15.0                     9.0
# 4                           0.0                     3.0
#
#    half_true_counts (float32)  \tmostly_true_counts (float32)  \
# 0                         1.0                             1.0
# 1                       160.0                           163.0
# 2                         3.0                             5.0
# 3                        20.0                            19.0
# 4                         2.0                             5.0
#
#    \tpants_on_fire_counts (float32)           context (string)
# 0                               0.0            a floor speech.
# 1                               9.0                     Denver
# 2                              44.0             a news release
# 3                               2.0        an interview on CNN
# 4                               1.0  a an online opinion-piece

# %%
df2 = df[['json_id', 'claim','object']].copy()

# %%
from pathlib import Path  
filepath = Path('../ThesisData/Data/Liar.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df2.to_csv(filepath)

# %%
from PIPE_LINE_V3 import readability_computation, compress_doc, VADER_score, process_text

df2[['flesch_kincaid_reading_ease', 'compressed_size', 'vader_neg', 'vader_neu', 'vader_pos', 'vader_compound']] = f

# %%
df2.head()
# Out:
#       json_id        claim                                             object  \
# 0  10540.json    half-true  When did the decline of coal start? It started...
# 1    324.json  mostly-true  Hillary Clinton agrees with John McCain "by vo...
# 2   1123.json        false  Health care reform legislation is likely to ma...
# 3   9028.json    half-true  The economic turnaround started at the end of ...
# 4  12465.json         true  The Chicago Bears have had more starting quart...
#
#    flesch_kincaid_reading_ease  compressed_size  vader_neg  vader_neu  \
# 0                    71.815000          11443.0      0.000      0.902
# 1                    71.781579           9089.0      0.107      0.687
# 2                    53.655000           5511.0      0.000      0.606
# 3                    61.325000           4708.0      0.000      1.000
# 4                    54.096667          12205.0      0.119      0.828
#
#    vader_pos  vader_compound
# 0      0.098          0.3612
# 1      0.206          0.3182
# 2      0.394          0.7579
# 3      0.000          0.0000
# 4      0.053         -0.4601

# %%
df2.to_csv('Computed_liar.csv')
